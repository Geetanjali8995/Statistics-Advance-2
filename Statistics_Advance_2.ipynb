# %% [markdown]
# #**Theoretical Questions**
# Q.1. What is hypothesis testing in statistics?
#
# Ans:Hypothesis testing in statistics is a method used to make decisions or inferences about a population based on sample data. It helps you determine whether there's enough evidence in a sample to support or reject a specific claim about a population parameter.
#
#  Key Concepts:
#
# 1.Hypotheses:
#
# - Null Hypothesis (H₀): The default or original assumption (e.g., "There is no difference").
#
# - Alternative Hypothesis (H₁ or Ha): What you're trying to prove (e.g., "There is a difference").
#
# 2.Test Statistic:
#
# - A value calculated from sample data that’s used to test the hypothesis (e.g., a t-score or z-score).
#
# 3.Significance Level (α):
#
# - The probability of rejecting the null hypothesis when it’s actually true (commonly set at 0.05 or 5%).
#
# 4.p-value:
#
# - The probability of obtaining a result as extreme as (or more extreme than)
# the observed result, assuming the null hypothesis is true.
#
# ---
#
# Q.2 What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
# Ans:
#
# **Null Hypothesis (H₀):**
#
# The null hypothesis is the default assumption or status quo. It suggests that there is no effect, no difference, or nothing has changed.
#
# It's what you're trying to test against.
#
# It’s often a statement of equality (e.g., =, ≥, ≤).
#
# Example:
# H₀: The average test score is equal to 70.
# (This means you assume there's no difference from the expected score.)
#
# **Alternative Hypothesis (H₁ or Ha):**
#
# The alternative hypothesis is what you believe might be true instead of the null. It suggests that there is a difference, an effect, or a change.
#
# It’s what you try to find evidence for.
#
# It's usually a statement of inequality (≠, <, >).
#
# Example:
# H₁: The average test score is not equal to 70.
# (This means you're testing to see if there's a significant change.)
#
# ---
#
# Q.3.What is the significance level in hypothesis testing, and why is it important?
#
# Ans:
# The significance level, usually denoted as α (alpha), is the threshold you set to decide whether or not to reject the null hypothesis.
#
# It represents the probability of making a Type I error, which means rejecting the null hypothesis when it’s actually true (a false positive).
#
#  Why is it Important?
#
#  1.Sets the bar for evidence:
#
# - It defines how much evidence you need to reject H₀.
# - Lower α = stronger evidence required.
#
# 2.Controls risk:
#
# - It limits how often you’re willing to make a false alarm (rejecting something that’s actually true).
#
# 3.Helps with decision-making:
#
# - If p-value ≤ α, you reject H₀ (evidence is strong enough).
# - If p-value > α, you do not reject H₀ (evidence isn’t strong enough).
#
#  **Example:**
#
# Suppose you're testing whether a new teaching method improves scores.
#
# - H₀: New method has no effect.
#
# - You set α = 0.05 (5% chance you're wrong if you reject H₀).
#
# - You calculate a p-value of 0.03.
#
# Since 0.03 < 0.05, you reject H₀ and conclude the new method likely has an effect — with a 5% risk of being wrong.
#
# ---
#
# Q.4.What does a P-value represent in hypothesis testing?
#
# Ans:
#
# The p-value is the probability of getting a result at least as extreme as the one you observed if the null hypothesis (H₀) is true.
#
# In simpler terms:
#
# It tells you how surprising your results are under the assumption that H₀ is correct.
#
# P-value:Small (e.g. ≤ 0.05)
#
# Interpretation: Your result is unlikely under H₀ → reject H₀
#
#
# P-value:Large (e.g. > 0.05)
#
# Interpretation: Your result is likely under H₀ → do not reject H₀
#
#
# Example:
# You're testing if a coin is fair.
# - H₀: The coin is fair (P = 0.5).
# - You flip it 100 times and get 80 heads.
# - The p-value is the probability of getting 80 or more heads out of 100 if the coin is actually fair.
#
# If that p-value is 0.002, it means:
#
# - There’s a 0.2% chance this result happened by random chance.
#
# - Since 0.002 < 0.05, you’d likely reject H₀ and suspect the coin is not fair.
#
#
#
# ---
# Q.5.How do you interpret the P-value in hypothesis testing?
#
# Ans:The P-value (probability value) in hypothesis testing helps you determine the strength of evidence against the null hypothesis. Here's how to interpret it:
#
# **Definition:** The P-value is the probability of obtaining a test statistic at least as extreme as the one observed, assuming the null hypothesis is true.
#
#
# **Interpretation:**
# - Low P-value (typically ≤ 0.05): Strong evidence against the null hypothesis → Reject the null hypothesis.
#
# - High P-value (> 0.05): Weak evidence against the null hypothesis → Fail to reject the null hypothesis.
#
# Example:
# If you're testing whether a new drug is more effective than a placebo:
#
# Null hypothesis (H₀): There is no difference.
#
# If your test yields a P-value of 0.02, it means there's a 2% chance you'd see this result or more extreme if the drug had no real effect. Since 0.02 < 0.05, you'd reject the null and conclude the drug likely works.

# %% [markdown]
# Q.6. What are Type 1 and Type 2 errors in hypothesis testing?
#
# Ans: In hypothesis testing, Type I and Type II errors represent two ways you can make a mistake when drawing conclusions about your hypothesis:
#
# **Type I Error (False Positive)**
#
# - Definition: Rejecting the null hypothesis (H₀) when it is actually true.
#
# - Analogy: Convicting an innocent person.
#
# - Probability: Denoted by α (alpha) — commonly set at 0.05.
#
# - Example: Concluding a new drug works better than a placebo when, in fact, it doesn’t.
#
# **Type II Error (False Negative)**
#
# - Definition: Failing to reject the null hypothesis when the alternative hypothesis (H₁) is actually true.
#
# - Analogy: Letting a guilty person go free.
#
# - Probability: Denoted by β (beta).
#
# - Power of a test:
# 1
# −
# 𝛽 ; the probability of correctly detecting a real effect.

# %% [markdown]
# Q.7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# Ans:The key difference between a one-tailed and a two-tailed test in hypothesis testing lies in the direction of the hypothesis and where you look for evidence against the null hypothesis.
#
# **One-Tailed Test:**
#
# - Definition: Tests for an effect in only one direction.
#
# - Use When: You have a specific directional hypothesis (e.g., greater than or less than).
#
# - Example:
# H₀: μ ≤ 100
# H₁: μ > 100 (you're only interested if the mean is greater than 100)
#
# - Rejection Region: Entire alpha (e.g., 0.05) is placed in one tail of the distribution.
#
# **Two-Tailed Test:**
#
# - Definition: Tests for an effect in either direction (increase or decrease).
#
# - Use When: You're interested in any difference, regardless of direction.
#
# - Example:
# H₀: μ = 100
#
# H₁: μ ≠ 100 (you're testing if the mean is different, either higher or lower)
#
# - Rejection Region: Alpha is split between both tails (e.g., 0.025 in each tail if α = 0.05).

# %% [markdown]
# Q.8. What is the Z-test, and when is it used in hypothesis testing?
#
# Ans:The Z-test is a statistical test used in hypothesis testing to determine whether there is a significant difference between sample and population means (or between two sample means), assuming the data follows a normal distribution and the population variance is known.
#
# **When to Use the Z-test:**
#
# - Sample size is large (usually n ≥ 30).
#
# - The population standard deviation (σ) is known.
#
# - The population is normally distributed or the Central Limit Theorem applies (for large samples).

# %% [markdown]
# Q.9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
# Ans: **How to Calculate the Z-score**
#
# The Z-score is calculated using the formula:
#
# Xˉ−μ/σ/ √n
#
#
# Where:
#
# - 𝑋ˉ: Sample mean
# - 𝜇: Population mean (under the null hypothesis)
# - 𝜎: Population standard deviation
# - 𝑛: Sample size
#
# **What the Z-score Represents in Hypothesis Testing**
#
# The Z-score tells you how many standard errors your observed sample mean is away from the population mean under the null hypothesis. In other words, it measures how unusual or extreme your sample result is, assuming the null hypothesis is true.
#
# **Interpretation:**
# - A Z-score of 0 means the sample mean equals the population mean.
#
# - A positive Z means the sample mean is above the population mean.
#
# - A negative Z means it is below the population mean.
#
# - Larger absolute Z-scores indicate stronger evidence against the null hypothesis.

# %% [markdown]
# Q.10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
# Ans:The T-distribution (or Student’s T-distribution) is a probability distribution that is similar to the normal distribution but has heavier tails. It’s used in hypothesis testing when you're working with small samples and unknown population standard deviation.
#
# **When to Use the T-Distribution Instead of the Normal Distribution (Z-distribution):**
#
# | Condition                         | Use Z-distribution? | Use T-distribution? |
# | --------------------------------- | ------------------- | ------------------- |
# | **Sample size ≥ 30** and σ known  | ✅ Yes               | ❌ No                |
# | **Sample size < 30** or σ unknown | ❌ No                | ✅ Yes               |
#
#
# **Use the T-distribution when:**
# - Sample size is small (usually n < 30).
#
# - The population standard deviation (σ) is unknown.
#
# - The population is normally distributed, or the sample is roughly symmetric (especially important for small n).

# %% [markdown]
# Q.11. What is the difference between a Z-test and a T-test?
#
# Ans:The Z-test and T-test are both used in hypothesis testing to determine whether there's a significant difference between sample statistics and population parameters — but they differ in when and how they are used.
#
#
# | Feature                               | **Z-test**                                                        | **T-test**                                          |
# | ------------------------------------- | ----------------------------------------------------------------- | --------------------------------------------------- |
# | **Population standard deviation (σ)** | **Known**                                                         | **Unknown**                                         |
# | **Sample size**                       | **Large** (typically $n \geq 30$)                                 | **Small** (typically $n < 30$)                      |
# | **Distribution used**                 | **Standard normal distribution** (Z-distribution)                 | **Student’s T-distribution**                        |
# | **Tail heaviness**                    | **Less** (narrower tails)                                         | **More** (heavier tails to account for variability) |
# | **Test statistic formula**            | $Z = \frac{\bar{X} - \mu}{\sigma/\sqrt{n}}$                       | $t = \frac{\bar{X} - \mu}{s/\sqrt{n}}$              |
# | **Use cases**                         | Comparing sample mean to population mean (σ known), large samples | Comparing means when σ unknown or for small samples |
# | **Converges to normal?**              | Already normal                                                    | Approaches normal as $n \to \infty$                 |
#
# When to Use Each:
#
# Use a Z-test when:
#
# - Population standard deviation is known.
#
# - Sample size is large.
#
# Use a T-test when:
#
# - Population standard deviation is unknown.
#
# - Sample size is small (and approximately normally distributed).

# %% [markdown]
# Q.12. What is the T-test, and how is it used in hypothesis testing?
#
# Ans:A T-test evaluates the null hypothesis (H₀), which typically states that there is no difference between two groups. If the T-test yields a p-value below a chosen significance level (e.g., 0.05), we reject the null hypothesis.
#
# **Step-by-Step: How the T-test is Used in Hypothesis Testing**
#
# 1.State the Hypotheses:
# - Null Hypothesis (H₀): Assumes no difference or no effect.
#
# Example: The mean weight loss for two diets is the same.
# 𝐻
# 0
# :
# 𝜇
# 1
# =
# 𝜇
# 2
# - Alternative Hypothesis (H₁): Assumes there is a difference or effect.
#
# Example: One diet leads to greater weight loss.
# 𝐻
# 1
# :
# 𝜇
# 1
# ≠
# 𝜇
# 2
#
#
#
# 2.Choose the Type of T-test
# - One-sample T-test: Compare sample mean to known value.
#
# - Independent two-sample T-test: Compare two unrelated group means.
#
# - Paired T-test: Compare means from the same group at two times.
#
# 3.Set the Significance Level (α)
# - Common choice: 0.05
#
# - This is the probability of rejecting H₀ when it is actually true (Type I error).
#
# 4.Calculate the T-statistic
# - Measures how far your sample statistic is from the null hypothesis.
#
# - Formula depends on the T-test type.
#
# 5.Determine Degrees of Freedom (df)
# - Needed to find the critical value or p-value from the T-distribution.
#
# 6.Find the P-value
# - This is the probability of getting your observed result (or more extreme) if the null hypothesis is true.
#
# 7.Make a Decision
# - If p-value ≤ α: Reject H₀ → evidence supports H₁.
#
# - If p-value > α: Fail to reject H₀ → not enough evidence to support H₁.

# %% [markdown]
# Q.13.  What is the relationship between Z-test and T-test in hypothesis testing?
#
# Ans:The Z-test and T-test are both statistical methods used in hypothesis testing to compare sample statistics (like means) and draw conclusions about population parameters. They are conceptually similar but used under different conditions.
#
#
# **Relationship Between Z-test and T-test**
#
# | Feature            | **Z-test**                                              | **T-test**                                                                  |
# | ------------------ | ------------------------------------------------------- | --------------------------------------------------------------------------- |
# | **Use Case**       | When population **standard deviation (σ)** is **known** | When population **standard deviation is unknown**                           |
# | **Sample Size**    | Typically **large** (n ≥ 30)                            | Typically **small** (n < 30)                                                |
# | **Distribution**   | Uses **standard normal distribution (Z)**               | Uses **t-distribution**                                                     |
# | **Shape**          | Symmetrical and fixed                                   | Symmetrical but **flatter and wider** (more conservative for small samples) |
# | **Converges to Z** | —                                                       | As n → ∞, the t-distribution approaches the normal (Z) distribution         |

# %% [markdown]
# Q.14. What is a confidence interval, and how is it used to interpret statistical results?
#
# Ans: A confidence interval (CI) is a range of values that's used to estimate an unknown population parameter (like a mean or proportion) based on sample data. It gives you both an estimate and a measure of uncertainty around that estimate.
#
# **How It's Used to Interpret Results**
#
# 1.Estimation: CIs provide a range, not just a point estimate. This helps quantify uncertainty.
#
# 2.Hypothesis Testing:
#
# - If a confidence interval for a mean difference (e.g., Drug A − Drug B) includes 0, it suggests no significant difference.
#
# - If a CI for a proportion includes the value under the null hypothesis, we fail to reject the null.
#
# Interpretation Example:
#
# Let’s say you compute a 95% CI for a population mean as [48.2, 51.8]:
#
# - This does not mean there's a 95% chance the true mean is in that interval (that’s a common mistake).
#
# - It means: If you repeated the study 100 times, about 95 of the CIs would contain the true population mean.

# %% [markdown]
# Q.15.What is the margin of error, and how does it affect the confidence interval?
#
# Ans:The margin of error (MOE) is the amount that is added and subtracted from a sample statistic (like a mean or proportion) to create a confidence interval. It reflects the level of uncertainty or potential error in your estimate due to sampling variability.
#
# Margin of Error=z
# ∗
#  ⋅
#  σ/√
# n
#
# - 𝑧∗
#  : Critical value from the Z- or T-distribution (depends on confidence level)
#
# - 𝜎: Population standard deviation (or sample standard deviation if population is unknown)
#
# - 𝑛: Sample size
#
# **How It Affects the Confidence Interval:**
#
# The confidence interval (CI) is constructed as:
#
# CI=
# x
# ˉ
#  ±Margin of Error
#
#  So, a larger MOE → a wider confidence interval, meaning less precision.
# A smaller MOE → a narrower interval, meaning more precision.
#
# What Influences the Margin of Error?

# %% [markdown]
# Q.16. How is Bayes' Theorem used in statistics, and what is its significance?
#
# Ans : Bayes' Theorem is a fundamental concept in statistics and probability theory that allows us to update the probability of a hypothesis based on new evidence. It's central to Bayesian inference, a powerful framework for reasoning under uncertainty.
#
# **Bayes' Theorem Formula:**
#
# P(A/B)=P(B/A).P(A)/P(B)
#
# Where:
# P(A/B)=  Posterior probability: Probability of hypothesis
# 𝐴 given data 𝐵
#
# P(B/A)= Likelihood: Probability of data
# 𝐵 assuming hypothesis 𝐴 is true
#
# P(A)= Prior probability: Belief about 𝐴 before seeing data
#
# P(B)=  Marginal likelihood: Total probability of the data under all hypotheses.
#
# **How Bayes’ Theorem is Used in Statistics**
#
# 1.Bayesian Inference:
#
# Instead of producing a single estimate, Bayesian methods produce a distribution of beliefs about the parameter.
#
# Used in:
#
# - Estimating population parameters
#
# - Hypothesis testing
#
# - Predictive modeling
#
# 2.Medical Diagnostics:
#
# - Example: Given a positive test result, what is the probability that a patient actually has the disease?
#
# - Bayes' theorem helps update the probability based on test accuracy and disease prevalence.
#
# 3.Machine Learning & AI:
#
# Naive Bayes Classifier: A simple yet powerful algorithm based on Bayes’ theorem with strong (naive) independence assumptions.
#
# Used in:
#
# - Spam detection
#
# - Sentiment analysis
#
# - Document classification
#
# 4.Risk Analysis & Decision Making:
#
# - In business, finance, and engineering, Bayes’ theorem helps update risk assessments when new data is available.
#
# 5.Genetics & Forensics:
#
# - Used to compute the probability of certain genetic traits or to evaluate the likelihood of forensic evidence matching a suspect.
#
# **Significance of Bayes’ Theorem:**
#
# - Intuitive reasoning framework: Mimics how humans revise beliefs with new information.
#
# - Handles uncertainty well: Especially valuable when data is sparse or noisy.
#
# - Flexible: Works with complex models and hierarchical structures.
#
# - Foundation of modern statistical modeling, especially in Bayesian statistics.

# %% [markdown]
# Q.17.  What is the Chi-square distribution, and when is it used?
#
# Ans: The Chi-square (χ²) distribution is a probability distribution that arises frequently in statistics, especially in hypothesis testing and inferential statistics.
#
# The Chi-square distribution is the distribution of a sum of the squares of independent standard normal variables. If
# 𝑍
# 1
# ,
# 𝑍
# 2
# ,
# .
# .
# .
# ,
# 𝑍
# 𝑘
# are independent standard normal variables (mean = 0, std dev = 1),
#
# then:
#
# χ
# 2
#  =Z
# 1
# 2
# ​
#  +Z
# 2
# 2
# ​
#  +⋯+Z
# k
# 2
# ​
#
# It has one parameter: the degrees of freedom (df), usually a positive integer.
#
#
# **When is the Chi-square Distribution Used?**
#
# 1.Chi-square Test for Independence:
#
# - Purpose: To test whether two categorical variables are independent.
#
# - Example: Is gender independent of purchasing preference?
#
# Test statistic:
#
# χ
# 2
#  =∑
# E
# (O−E)
# 2
#
# ​
# Where
# 𝑂= observed frequency,
#
# 𝐸= expected frequency
#
# 2.Chi-square Goodness-of-Fit Test:
#
# - Purpose: To test if a categorical variable follows a specific distribution.
#
# - Example: Do dice rolls follow a uniform distribution?
#
# 3.Testing Variance:
#
# - In normal distributions, Chi-square is used to test hypotheses about population variance.
#
# - Example: Is the variance of a machine’s output within acceptable limits?
#
# 4.Confidence Intervals for Variance:
#
# - For a normally distributed population, confidence intervals for variance are based on the Chi-square distribution.

# %% [markdown]
# Q.18. What is the Chi-square goodness of fit test, and how is it applied?
#
# Ans:The Chi-square Goodness of Fit Test is a statistical test used to determine whether a set of observed categorical data matches an expected distribution. It tells us how well the observed data "fits" the expected theoretical distribution.
#
# **Steps to Apply the Chi-square Goodness of Fit Test:**
#
# 1. State Hypotheses
# Null hypothesis (H₀): Observed data follows the expected distribution.
#
#  Alternative hypothesis (H₁): Observed data does not follow the expected distribution.
#
# 2. Calculate Expected Frequencies
# Multiply total number of observations by each category's expected proportion.
#
#  𝐸
# 𝑖
# =
# Total Observations
# ×
# Expected Proportion
# 𝑖
# E
# i
# ​
#  =Total Observations×Expected Proportion
# i
# ​
#
# 3. Compute the Test Statistic
# Use the Chi-square formula to compare observed and expected frequencies.
#
# 4. Determine Degrees of Freedom
# 𝑑
# 𝑓
# =
# 𝑘
# −
# 1
# df=k−1, where k is the number of categories.
#
# 5. Find the Critical Value or p-value
# Use Chi-square distribution tables or software.
#
# 6. Make a Decision
# If
# 𝜒
# 2
# χ
# 2
#   statistic > critical value or p-value < α (e.g., 0.05), reject H₀.

# %% [markdown]
# Q.19. What is the F-distribution, and when is it used in hypothesis testing?
#
# Ans: The F-distribution is a probability distribution that arises frequently in hypothesis testing, particularly when comparing variances or evaluating multiple group means. It’s named after Sir Ronald Fisher, a pioneer in statistics.
#
#  **Definition:**
#
# The F-distribution is the distribution of the ratio of two scaled chi-square variables:
#
#  When Is the F-distribution Used in Hypothesis Testing?
# 1. ANOVA (Analysis of Variance)
# Purpose: To test if there are significant differences between three or more group means
#
#  Test statistic:
#
#  𝐹=Variance Between Groups/Variance Within Groups
#
#  If the F-value is significantly large, at least one group mean differs.
#
# 2. Test for Equality of Variances (F-test)
# Purpose: To compare the variances of two populations.
#
#  Example: Are the variances of test scores from two teaching methods the same?
#
# 3. Regression Analysis
# Purpose: To test the overall significance of a multiple linear regression model.
#
#  F-test checks if at least one predictor variable has a non-zero coefficient.

# %% [markdown]
# Q.20.What is an ANOVA test, and what are its assumptions?
#
# Ans:The ANOVA test (Analysis of Variance) is a statistical method used to compare the means of three or more groups to determine if at least one group mean is significantly different from the others.
#
# **Purpose of ANOVA**
#
# To test the hypothesis:
#
# - Null hypothesis (H₀): All group means are equal.
#
# - Alternative hypothesis (H₁): At least one group mean is different.
#
# **Assumptions of ANOVA**
#
# 1.Independence of Observations:
#
# - Each sample or group must be randomly and independently drawn.
#
# 2.Normality
#
# - The data in each group should be approximately normally distributed.
#
# - Assessed using tests like Shapiro-Wilk or visual methods like Q-Q plots.
#
# 3.Homogeneity of Variance (Homoscedasticity)
#
# - All groups should have equal variances.
#
# - Tested using Levene’s test or Bartlett’s test.
#
# If these assumptions are violated, ANOVA results may not be reliable. In such cases, consider:
#
# - Non-parametric alternatives (e.g., Kruskal-Wallis test)
#
# - Transforming the data

# %% [markdown]
# Q.21.  What are the different types of ANOVA tests?
#
# Ans:There are several types of ANOVA tests, each suited to different experimental designs and data structures. Here’s a breakdown of the main types of ANOVA:
#
# **1.One-Way ANOVA (Single-Factor ANOVA):**
#
# - Use case: Compare the means of three or more independent groups based on one categorical independent variable (factor).
#
# - Example: Comparing average exam scores across three teaching methods.
#
# - Tests if group means are significantly different.
#
# **2. Two-Way ANOVA (Factorial ANOVA):**
#
# - Use case: Evaluate the effect of two independent variables on a continuous dependent variable.
#
# - Example: Study effects of teaching method and gender on test scores.
#
# - Can test for:
#
#   Main effect of Factor A
#
#   Main effect of Factor B
#
#   Interaction effect between A and B
#
# **3. Repeated Measures ANOVA:**
#
# - Use case: Used when the same subjects are measured multiple times (longitudinal data).
#
# - Example: Measuring blood pressure of patients before, during, and after treatment.
#
# - Accounts for within-subject variability.
#
# **4. Mixed-Design ANOVA (Split-Plot ANOVA):**
#
# - Use case: Combines both between-subject and within-subject factors.
#
# - Example: Measuring test scores over time for students across different schools (between-subject: school, within-subject: time).
#
# **5. Multivariate ANOVA (MANOVA):**
#
# - Use case: Extends ANOVA to handle multiple dependent variables simultaneously.
#
# - Example: Assessing the impact of a training program on productivity and job satisfaction together.
# - Captures correlations between dependent variables.
#
# **6. ANCOVA (Analysis of Covariance):**
#
# - Use case: ANOVA with one or more continuous covariates that you want to control for.
#
# - Example: Comparing teaching methods on test scores while controlling for prior knowledge.

# %% [markdown]
# Q.22.  What is the F-test, and how does it relate to hypothesis testing?
#
# Ans:The F-test is a statistical test used to compare variances or model fits by analyzing the ratio of two variances. It’s based on the F-distribution, and it plays a central role in ANOVA and regression analysis.
#
# Definition
# The F-statistic is the ratio of two variances:
#
# 𝐹
# =
# Variance of group 1/
# Variance of group 2
#
#
# If both groups come from the same population, we expect this ratio to be close to 1. If the F-value is significantly greater than 1, it suggests the variances are different.
#
# **Purpose in Hypothesis Testing**
#
# The F-test evaluates whether the observed differences between groups or models are statistically significant.

# %% [markdown]
# **Practical**

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
#interpret the results
import numpy as np
from scipy.stats import norm

# Sample data
sample = [72, 68, 75, 70, 69, 74, 73, 71, 68, 76]
sample_mean = np.mean(sample)
sample_size = len(sample)

# Known population values
population_mean = 70
population_std = 5  # σ known

# Z-test statistic
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Output
print(f"Sample Mean = {sample_mean:.2f}")
print(f"Z-score = {z_score:.3f}")
print(f"P-value = {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference between sample and population means.")
# Out:
# Sample Mean = 71.60
# Z-score = 1.012
# P-value = 0.3116
# Fail to reject the null hypothesis: No significant difference between sample and population means.

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
import numpy as np
from scipy import stats

# Step 1: Simulate sample data
np.random.seed(42)  # for reproducibility
sample = np.random.normal(loc=77, scale=10, size=30)  # mean=77, std=10, n=30

# Step 2: Define population mean for comparison
population_mean = 75

# Step 3: Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(sample, population_mean)

# Step 4: Print results
print(f"Sample Mean: {np.mean(sample):.2f}")
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# Sample Mean: 75.12
# T-statistic: 0.072
# P-value: 0.9430
# Fail to reject the null hypothesis: No significant difference.

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean
import numpy as np
from scipy.stats import norm

# Sample data
sample = [72, 68, 75, 70, 69, 74, 73, 71, 68, 76]
sample_mean = np.mean(sample)
sample_size = len(sample)

# Known population parameters
population_mean = 70
population_std = 5  # Known population standard deviation (σ)

# Z-test statistic
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Print results
print(f"Sample Mean = {sample_mean:.2f}")
print(f"Z-score = {z_score:.3f}")
print(f"P-value = {p_value:.4f}")

# Conclusion
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# Sample Mean = 71.60
# Z-score = 1.012
# P-value = 0.3116
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %%
#4.  Perform a two-tailed Z-test using Python and visualize the decision region on a plot
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
sample = [72, 68, 75, 70, 69, 74, 73, 71, 68, 76]
sample_mean = np.mean(sample)
sample_size = len(sample)

# Known population parameters
population_mean = 70
population_std = 5  # σ
alpha = 0.05  # Significance level

# Z-test calculation
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Critical z-values for two-tailed test
z_critical = norm.ppf(1 - alpha / 2)

# Print results
print(f"Sample Mean = {sample_mean:.2f}")
print(f"Z-score = {z_score:.3f}")
print(f"P-value = {p_value:.4f}")
print(f"Z-critical (±) = ±{z_critical:.3f}")

# Decision
if abs(z_score) > z_critical:
    print("Reject the null hypothesis: Significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")

# -------- Visualization --------
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.figure(figsize=(10, 5))
plt.plot(x, y, label='Standard Normal Distribution')

# Shaded rejection regions
plt.fill_between(x, y, where=(x <= -z_critical), color='red', alpha=0.3, label='Rejection Region (left)')
plt.fill_between(x, y, where=(x >= z_critical), color='red', alpha=0.3, label='Rejection Region (right)')
# Out:
# Sample Mean = 71.60
# Z-score = 1.012
# P-value = 0.3116
# Z-critical (±) = ±1.960
# Fail to reject the null hypothesis: No significant difference.

# %%
#5.  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2(mu0, mu1, sigma, n, alpha=0.05):
    """
    Visualizes Type I and Type II errors using hypothesis testing.

    Parameters:
    - mu0: Mean under H0
    - mu1: Mean under H1
    - sigma: Population standard deviation
    - n: Sample size
    - alpha: Significance level
    """

    # Standard error
    se = sigma / np.sqrt(n)

    # Critical value for one-tailed Z-test (right-tailed)
    z_alpha = norm.ppf(1 - alpha)
    critical_value = mu0 + z_alpha * se

    # Type II error (beta)
    z_beta = (critical_value - mu1) / se
    beta = norm.cdf(z_beta)
    power = 1 - beta

    # X range for plotting
    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)
    y0 = norm.pdf(x, mu0, se)
    y1 = norm.pdf(x, mu1, se)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y0, label=f'H₀: μ = {mu0}', color='blue')
    plt.plot(x, y1, label=f'H₁: μ = {mu1}', color='green')

    # Type I Error (alpha) area
    plt.fill_between(x, y0, where=(x >= critical_value), color='red', alpha=0.3, label='Type I Error (α)')

    # Type II Error (beta) area
    plt.fill_between(x, y1, where=(x < critical_value), color='orange', alpha=0.3, label='Type II Error (β)')

    # Critical value line
    plt.axvline(critical_value, color='black', linestyle='--', label=f'Critical Value = {critical_value:.2f}')

    # Labels and legend
    plt.title('Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print stats
    print(f"Critical Value: {critical_value:.2f}")
    print(f"Z (α): {z_alpha:.3f}")
    print(f"Z (β): {z_beta:.3f}")
    print(f"Type I Error (α): {alpha:.3f}")
    print(f"Type II Error (β): {beta:.3f}")
    print(f"Power of the Test (1 - β): {power:.3f}")

# Run the function
visualize_type1_type2(mu0=100, mu1=105, sigma=15, n=36, alpha=0.05)
# Out:
# Critical Value: 104.11
# Z (α): 1.645
# Z (β): -0.355
# Type I Error (α): 0.050
# Type II Error (β): 0.361
# Power of the Test (1 - β): 0.639

# %%
#6.  Write a Python program to perform an independent T-test and interpret the results
import numpy as np
from scipy.stats import ttest_ind

# Sample data (two independent groups)
group1 = [65, 70, 75, 68, 74, 72, 71, 69, 73, 70]
group2 = [80, 85, 82, 78, 84, 79, 83, 81, 77, 86]

# Perform independent t-test
t_stat, p_value = ttest_ind(group1, group2, equal_var=True)  # assume equal variance

# Print results
print(f"Group 1 Mean: {np.mean(group1):.2f}")
print(f"Group 2 Mean: {np.mean(group2):.2f}")
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two group means.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two group means.")
# Out:
# Group 1 Mean: 70.70
# Group 2 Mean: 81.50
# T-statistic: -8.035
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the two group means.

# %%
#7.  Perform a paired sample T-test using Python and visualize the comparison results
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Sample data: scores before and after training
before = [70, 72, 68, 65, 74, 69, 71, 67, 66, 68]
after  = [75, 74, 72, 70, 78, 72, 73, 70, 69, 71]

# Paired T-Test
t_stat, p_value = ttest_rel(after, before)

# Print Results
print(f"Mean Before: {np.mean(before):.2f}")
print(f"Mean After : {np.mean(after):.2f}")
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value    : {p_value:.4f}")

# Interpret Result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between before and after.")
else:
    print("Fail to reject the null hypothesis: No significant difference detected.")

# -----------------------
# Visualization
# -----------------------
x = np.arange(len(before))
width = 0.35

plt.figure(figsize=(10, 5))
plt.bar(x - width/2, before, width, label='Before', color='skyblue')
plt.bar(x + width/2, after,  width, label='After', color='lightgreen')

# Annotate bars
for i in x:
    plt.text(i - 0.2, before[i] + 0.5, str(before[i]), fontsize=9)
    plt.text(i + 0.1, after[i] + 0.5, str(after[i]), fontsize=9)

plt.title("Before vs After Training: Paired Sample Comparison")
plt.xlabel("Participant Index")
plt.ylabel("Score")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Mean Before: 69.00
# Mean After : 72.40
# T-statistic: 10.002
# P-value    : 0.0000
# Reject the null hypothesis: There is a significant difference between before and after.

# %%
#8.  Simulate data and perform both Z-test and T-test, then compare the results using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def compare_z_and_t_test():
    # -------------------------
    # Step 1: Simulate sample data
    # -------------------------
    np.random.seed(42)             # For reproducibility
    mu_pop = 100                   # Known population mean
    sigma_pop = 15                 # Known population std-dev (for Z-test)
    n = 25                         # Sample size

    # Generate sample from a normal distribution
    sample = np.random.normal(loc=103, scale=sigma_pop, size=n)

    # -------------------------
    # Step 2: Perform Z-test (σ known)
    # -------------------------
    sample_mean = np.mean(sample)
    z_stat = (sample_mean - mu_pop) / (sigma_pop / np.sqrt(n))
    p_z = 2 * (1 - stats.norm.cdf(abs(z_stat)))  # Two-tailed p-value

    # -------------------------
    # Step 3: Perform T-test (σ unknown)
    t_stat, p_t = stats.ttest_1samp(sample, mu_pop)

    # -------------------------
    # Step 4: Print results
    print("=== Summary ===")
    print(f"Sample size (n):         {n}")
    print(f"Sample mean:             {sample_mean:.3f}")
    print(f"Sample std. deviation:   {np.std(sample, ddof=1):.3f}\n")

    print("---- Z-test (σ known) ----")
    print(f"Z statistic:             {z_stat:.3f}")
    print(f"P-value (two-tailed):    {p_z:.4f}\n")

    print("---- T-test (σ unknown) ----")
    print(f"T statistic:             {t_stat:.3f}")
    print(f"P-value (two-tailed):    {p_t:.4f}")

    # -------------------------
    # Step 5: Visual comparison (bar plot)
    # -------------------------
    labels = ["Z-test", "T-test"]
    values = [p_z, p_t]

    plt.figure(figsize=(6, 4))
    plt.bar(labels, values, color=['steelblue', 'seagreen'])
    plt.ylabel("P-value")
    plt.title("Comparison of P-values: Z-test vs T-test")
    plt.ylim(0, 1)
    plt.axhline(0.05, color='red', linestyle='--', label='Significance level (α = 0.05)')
    plt.legend()
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Run the function
compare_z_and_t_test()
# Out:
# === Summary ===
# Sample size (n):         25
# Sample mean:             100.547
# Sample std. deviation:   14.348
#
# ---- Z-test (σ known) ----
# Z statistic:             0.182
# P-value (two-tailed):    0.8552
#
# ---- T-test (σ unknown) ----
# T statistic:             0.191
# P-value (two-tailed):    0.8503

# %%
#9.  Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    """
    Calculates the confidence interval for a sample mean using t-distribution.

    Parameters:
        data (list or np.array): Sample data
        confidence (float): Confidence level (e.g., 0.95 for 95%)

    Returns:
        (lower_bound, upper_bound): Tuple containing the confidence interval
    """
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)  # standard error
    df = n - 1  # degrees of freedom
    t_crit = t.ppf((1 + confidence) / 2, df)  # two-tailed t critical value

    margin_of_error = t_crit * std_err
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return lower_bound, upper_bound
# Sample data
sample = [72, 68, 75, 70, 69, 74, 73, 71, 68, 76]

# 95% Confidence Interval
ci = confidence_interval(sample, confidence=0.95)
print(f"95% Confidence Interval for the mean: ({ci[0]:.2f}, {ci[1]:.2f})")
# Out:
# 95% Confidence Interval for the mean: (69.54, 73.66)

# %% [markdown]
# **Significance of Confidence Interval:**
#
# A confidence interval gives a range of values within which we can be confident the true population mean lies, based on our sample:
#
# - A 95% confidence interval means:
#
#   “If we took 100 random samples and built a CI for each, about 95 of them would contain the true population mean.”
#
# - It reflects:
#
#   The sample mean
#
#   The sample size
#
#   The variability in the data
#
#   The confidence level (usually 90%, 95%, or 99%)

# %%
#Q.10 Write a Python program to calculate the margin of error for a given confidence level using sample data
import numpy as np
from scipy.stats import t

def calculate_margin_of_error(data, confidence=0.95):
    """
    Calculates the margin of error using the t-distribution.

    Parameters:
        data (list or np.array): Sample data
        confidence (float): Confidence level (e.g., 0.95 for 95%)

    Returns:
        margin_of_error: The margin of error for the sample mean
    """
    data = np.array(data)
    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    standard_error = sample_std / np.sqrt(n)

    # Degrees of freedom
    df = n - 1

    # Critical value from t-distribution
    t_critical = t.ppf((1 + confidence) / 2, df)

    # Margin of Error
    margin_of_error = t_critical * standard_error

    return margin_of_error, sample_mean

# Example usage
sample_data = [72, 68, 75, 70, 69, 74, 73, 71, 68, 76]
confidence_level = 0.95

me, mean = calculate_margin_of_error(sample_data, confidence=confidence_level)
print(f"Sample Mean: {mean:.2f}")
print(f"Margin of Error at {int(confidence_level*100)}% Confidence: ±{me:.2f}")
print(f"Confidence Interval: ({mean - me:.2f}, {mean + me:.2f})")
# Out:
# Sample Mean: 71.60
# Margin of Error at 95% Confidence: ±2.06
# Confidence Interval: (69.54, 73.66)

# %%
#Q.11  Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

def bayesian_coin_inference(alpha_prior=2, beta_prior=2, n_trials=20, k_success=14, confidence=0.95):
    """
    Performs Bayesian inference using a Beta prior and Binomial likelihood.

    Parameters:
        alpha_prior (int): Prior successes (shape parameter of Beta)
        beta_prior (int): Prior failures (shape parameter of Beta)
        n_trials (int): Number of coin flips
        k_success (int): Number of heads observed
        confidence (float): Credible interval level (default 0.95)

    Outputs:
        - Prior and posterior plots
        - Posterior mean and credible interval
    """
    # Posterior parameters (Bayes update for Beta-Binomial model)
    alpha_post = alpha_prior + k_success
    beta_post = beta_prior + (n_trials - k_success)

    # Create grid and evaluate distributions
    x = np.linspace(0, 1, 1000)
    prior_pdf = beta.pdf(x, alpha_prior, beta_prior)
    post_pdf = beta.pdf(x, alpha_post, beta_post)

    # Plot Prior and Posterior
    plt.figure(figsize=(8, 5))
    plt.plot(x, prior_pdf, label=f"Prior: Beta({alpha_prior}, {beta_prior})", color='skyblue', linewidth=2)
    plt.plot(x, post_pdf, label=f"Posterior: Beta({alpha_post}, {beta_post})", color='orange', linewidth=2)
    plt.axvline(alpha_post / (alpha_post + beta_post), color='red', linestyle='--', label="Posterior Mean")

    plt.title("Bayesian Update: Coin Flip Bias Estimation")
    plt.xlabel("Probability of Heads (p)")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

    # Posterior Summary
    posterior_mean = alpha_post / (alpha_post + beta_post)
    lower_bound, upper_bound = beta.ppf([(1 - confidence) / 2, (1 + confidence) / 2], alpha_post, beta_post)

    print("=== Bayesian Inference Results ===")
    print(f"Posterior Mean (expected p):      {posterior_mean:.3f}")
    print(f"{int(confidence * 100)}% Credible Interval:     ({lower_bound:.3f}, {upper_bound:.3f})")
    print(f"Posterior Distribution:           Beta({alpha_post}, {beta_post})")

# Run the program with default settings
bayesian_coin_inference()
# Out:
# === Bayesian Inference Results ===
# Posterior Mean (expected p):      0.667
# 95% Credible Interval:     (0.471, 0.836)
# Posterior Distribution:           Beta(16, 8)

# %%
#Q.12.  Perform a Chi-square test for independence between two categorical variables in Python
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Create a contingency table
data = {
    'Mobile':  [30, 20],   # [Males, Females]
    'Desktop': [20, 25],
    'Tablet':  [10, 15]
}
index = ['Male', 'Female']
contingency_table = pd.DataFrame(data, index=index)

print("Contingency Table:")
print(contingency_table)

# Step 2: Perform the Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Step 3: Output results
print("\n=== Chi-square Test Results ===")
print(f"Chi-square Statistic: {chi2:.3f}")
print(f"Degrees of Freedom:   {dof}")
print(f"P-value:              {p:.4f}")
print("\nExpected Frequencies:")
print(pd.DataFrame(expected, index=index, columns=contingency_table.columns))

# Step 4: Interpretation
alpha = 0.05
if p < alpha:
    print("\nConclusion: Reject the null hypothesis — there is a significant association.")
else:
    print("\nConclusion: Fail to reject the null hypothesis — no significant association.")
# Out:
# Contingency Table:
#         Mobile  Desktop  Tablet
# Male        30       20      10
# Female      20       25      15
#
# === Chi-square Test Results ===
# Chi-square Statistic: 3.556
# Degrees of Freedom:   2
# P-value:              0.1690
#
# Expected Frequencies:
#         Mobile  Desktop  Tablet
# Male      25.0     22.5    12.5
# Female    25.0     22.5    12.5
#
# Conclusion: Fail to reject the null hypothesis — no significant association.

# %%
#Q.13Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
#data
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Create observed contingency table
# Example: Gender vs Preferred Device
observed_data = {
    'Mobile':  [30, 20],   # [Males, Females]
    'Desktop': [20, 25],
    'Tablet':  [10, 15]
}
index = ['Male', 'Female']
observed = pd.DataFrame(observed_data, index=index)

# Display the observed table
print("Observed Frequencies (Contingency Table):")
print(observed)

# Step 2: Calculate expected frequencies using chi2_contingency
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

# Step 3: Display expected frequencies
expected_df = pd.DataFrame(expected, index=observed.index, columns=observed.columns)

print("\nExpected Frequencies (if variables are independent):")
print(expected_df)
# Out:
# Observed Frequencies (Contingency Table):
#         Mobile  Desktop  Tablet
# Male        30       20      10
# Female      20       25      15
#
# Expected Frequencies (if variables are independent):
#         Mobile  Desktop  Tablet
# Male      25.0     22.5    12.5
# Female    25.0     22.5    12.5

# %%
#Q.14  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution
import numpy as np
from scipy.stats import chisquare

# Step 1: Observed data (e.g., die rolls)
observed = np.array([10, 9, 11, 8, 12, 10])  # observed frequencies for faces 1–6

# Step 2: Expected data (e.g., uniform distribution)
expected = np.array([10] * 6)  # expected = total rolls / number of outcomes = 60/6 = 10

# Step 3: Perform the Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 4: Display results
print("=== Chi-square Goodness-of-Fit Test ===")
print(f"Observed Frequencies: {observed}")
print(f"Expected Frequencies: {expected}")
print(f"Chi-square Statistic: {chi2_stat:.3f}")
print(f"P-value:              {p_value:.4f}")

# Step 5: Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nConclusion: Reject the null hypothesis — the observed data does NOT fit the expected distribution.")
else:
    print("\nConclusion: Fail to reject the null hypothesis — the observed data fits the expected distribution.")
# Out:
# === Chi-square Goodness-of-Fit Test ===
# Observed Frequencies: [10  9 11  8 12 10]
# Expected Frequencies: [10 10 10 10 10 10]
# Chi-square Statistic: 1.000
# P-value:              0.9626
#
# Conclusion: Fail to reject the null hypothesis — the observed data fits the expected distribution.

# %%
#Q.15  Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Step 1: Set degrees of freedom (df)
dfs = [1, 2, 5, 10, 20]

# Step 2: Create grid of x values
x = np.linspace(0, 40, 500)

# Step 3: Plot Chi-square PDFs for different degrees of freedom
plt.figure(figsize=(10, 6))

for df in dfs:
    y = chi2.pdf(x, df)
    plt.plot(x, y, label=f'df = {df}', linewidth=2)

plt.title("Chi-square Distribution for Various Degrees of Freedom")
plt.xlabel("Chi-square Value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#.Q.16.  Implement an F-test using Python to compare the variances of two random samples
import numpy as np
from scipy.stats import f

def f_test(sample1, sample2, alpha=0.05):
    # Step 1: Calculate sample variances
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    # Step 2: Determine which variance is larger
    if var1 > var2:
        f_stat = var1 / var2
        dfn = len(sample1) - 1  # degrees of freedom numerator
        dfd = len(sample2) - 1  # degrees of freedom denominator
    else:
        f_stat = var2 / var1
        dfn = len(sample2) - 1
        dfd = len(sample1) - 1

    # Step 3: Calculate critical F value and p-value
    p_value = 2 * (1 - f.cdf(f_stat, dfn, dfd))  # two-tailed test

    # Step 4: Print results
    print("=== F-test for Equality of Variances ===")
    print(f"Sample 1 Variance: {var1:.4f}")
    print(f"Sample 2 Variance: {var2:.4f}")
    print(f"F-statistic:       {f_stat:.4f}")
    print(f"P-value:           {p_value:.4f}")

    # Step 5: Interpretation
    if p_value < alpha:
        print("Conclusion: Reject the null hypothesis – variances are significantly different.")
    else:
        print("Conclusion: Fail to reject the null hypothesis – no significant difference in variances.")

# Example usage
np.random.seed(42)
sample_A = np.random.normal(loc=50, scale=5, size=30)
sample_B = np.random.normal(loc=52, scale=10, size=30)

f_test(sample_A, sample_B)
# Out:
# === F-test for Equality of Variances ===
# Sample 1 Variance: 20.2503
# Sample 2 Variance: 86.6951
# F-statistic:       4.2812
# P-value:           0.0002
# Conclusion: Reject the null hypothesis – variances are significantly different.

# %%
#Q.17 Write a Python program to perform an ANOVA test to compare means between multiple groups and
#interpret the results
import numpy as np
from scipy.stats import f_oneway

# Step 1: Create sample data for 3 groups
np.random.seed(42)
group_A = np.random.normal(loc=60, scale=5, size=30)
group_B = np.random.normal(loc=65, scale=5, size=30)
group_C = np.random.normal(loc=70, scale=5, size=30)

# Step 2: Perform one-way ANOVA
f_stat, p_value = f_oneway(group_A, group_B, group_C)

# Step 3: Display results
print("=== One-Way ANOVA Test ===")
print(f"F-statistic: {f_stat:.3f}")
print(f"P-value:     {p_value:.4f}")

# Step 4: Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nConclusion: Reject the null hypothesis – at least one group mean is significantly different.")
else:
    print("\nConclusion: Fail to reject the null hypothesis – no significant difference among group means.")
# Out:
# === One-Way ANOVA Test ===
# F-statistic: 40.976
# P-value:     0.0000
#
# Conclusion: Reject the null hypothesis – at least one group mean is significantly different.

# %%
#Q.18.  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# Step 1: Simulate sample data for 3 groups
np.random.seed(42)
group_A = np.random.normal(loc=60, scale=5, size=30)
group_B = np.random.normal(loc=65, scale=5, size=30)
group_C = np.random.normal(loc=70, scale=5, size=30)

# Step 2: Combine data into a DataFrame for analysis and plotting
data = pd.DataFrame({
    'Score': np.concatenate([group_A, group_B, group_C]),
    'Group': ['A'] * len(group_A) + ['B'] * len(group_B) + ['C'] * len(group_C)
})

# Step 3: Perform One-Way ANOVA
f_stat, p_value = f_oneway(group_A, group_B, group_C)

# Step 4: Print ANOVA result
print("=== One-Way ANOVA Results ===")
print(f"F-statistic: {f_stat:.3f}")
print(f"P-value:     {p_value:.4f}")
if p_value < 0.05:
    print("Conclusion: Reject the null hypothesis – at least one group mean is significantly different.")
else:
    print("Conclusion: Fail to reject the null – group means are not significantly different.")

# Step 5: Plot results using Seaborn boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Group', y='Score', data=data, palette='Set2')
plt.title('One-Way ANOVA: Group Score Comparison')
plt.ylabel('Score')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# === One-Way ANOVA Results ===
# F-statistic: 40.976
# P-value:     0.0000
# Conclusion: Reject the null hypothesis – at least one group mean is significantly different.
# /tmp/ipython-input-10-1762185613.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Score', data=data, palette='Set2')

# %%
#Q.19  Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols

def check_anova_assumptions(data, dependent_var, group_var):
    """
    Check ANOVA assumptions: normality, independence (plot), and equal variances.

    Parameters:
    - data: pandas DataFrame containing the data.
    - dependent_var: name of the dependent variable (string).
    - group_var: name of the group/categorical variable (string).
    """

    # 1. Fit ANOVA model
    model = ols(f'{dependent_var} ~ C({group_var})', data=data).fit()
    residuals = model.resid

    print("\n### Normality Check (Shapiro-Wilk Test on Residuals) ###")
    shapiro_stat, shapiro_p = stats.shapiro(residuals)
    print(f"Shapiro-Wilk Test Statistic: {shapiro_stat:.4f}, p-value: {shapiro_p:.4f}")
    if shapiro_p > 0.05:
        print("Residuals appear to be normally distributed.")
    else:
        print("Residuals do not appear to be normally distributed.")

    # 2. Plot residuals to visually check independence & normality
    print("\n### Residual Plots ###")
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Q-Q plot for normality
    sm.qqplot(residuals, line='s', ax=axes[0])
    axes[0].set_title("Q-Q Plot of Residuals")

    # Residuals vs fitted values plot for independence
    fitted = model.fittedvalues
    axes[1].scatter(fitted, residuals, alpha=0.7)
    axes[1].axhline(0, color='red', linestyle='--')
    axes[1].set_xlabel("Fitted values")
    axes[1].set_ylabel("Residuals")
    axes[1].set_title("Residuals vs Fitted")

    plt.tight_layout()
    plt.show()

    # 3. Levene's Test for equal variances
    print("\n### Equal Variance Check (Levene's Test) ###")
    grouped_data = [group[dependent_var].values for name, group in data.groupby(group_var)]
    levene_stat, levene_p = stats.levene(*grouped_data)
    print(f"Levene’s Test Statistic: {levene_stat:.4f}, p-value: {levene_p:.4f}")
    if levene_p > 0.05:
        print("Variances appear to be equal across groups.")
    else:
        print("Variances do not appear to be equal across groups.")
# Example with sample data
df = pd.DataFrame({
    'score': np.random.normal(loc=70, scale=10, size=90),
    'group': np.repeat(['A', 'B', 'C'], 30)
})

check_anova_assumptions(df, dependent_var='score', group_var='group')
# Out:
# ### Normality Check (Shapiro-Wilk Test on Residuals) ###
# Shapiro-Wilk Test Statistic: 0.9750, p-value: 0.0801
# Residuals appear to be normally distributed.
#
# ### Residual Plots ###
# ### Equal Variance Check (Levene's Test) ###
# Levene’s Test Statistic: 1.1682, p-value: 0.3157
# Variances appear to be equal across groups.

# %%
#Q.20  Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
#results
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt

def two_way_anova_with_interaction(data, dependent_var, factor1, factor2):
    """
    Perform two-way ANOVA with interaction and visualize the results.

    Parameters:
    - data: pandas DataFrame
    - dependent_var: string, name of dependent variable
    - factor1: string, name of first independent variable
    - factor2: string, name of second independent variable
    """

    # Fit two-way ANOVA model with interaction
    formula = f'{dependent_var} ~ C({factor1}) + C({factor2}) + C({factor1}):C({factor2})'
    model = ols(formula, data=data).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)

    print("### Two-Way ANOVA Table ###")
    print(anova_table)

    # Interaction Plot
    print("\n### Interaction Plot ###")
    sns.pointplot(x=factor1, y=dependent_var, hue=factor2, data=data, dodge=True, markers='o', capsize=.1)
    plt.title("Interaction between Factors")
    plt.ylabel(dependent_var)
    plt.grid(True)
    plt.show()
# Sample dataset
np.random.seed(0)
df = pd.DataFrame({
    'Score': np.random.normal(loc=70, scale=10, size=120),
    'Teaching_Method': np.repeat(['A', 'B'], 60),
    'Classroom': np.tile(np.repeat(['X', 'Y', 'Z'], 20), 2)
})

# Perform two-way ANOVA
two_way_anova_with_interaction(df, dependent_var='Score',
                                factor1='Teaching_Method',
                                factor2='Classroom')
# Out:
# ### Two-Way ANOVA Table ###
#                                        sum_sq     df         F    PR(>F)
# C(Teaching_Method)                  37.557379    1.0  0.380361  0.538640
# C(Classroom)                        73.931805    2.0  0.374371  0.688564
# C(Teaching_Method):C(Classroom)   1740.328293    2.0  8.812562  0.000276
# Residual                         11256.512273  114.0       NaN       NaN
#
# ### Interaction Plot ###

# %%
#Q21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def plot_f_distribution(dfn=5, dfd=20, alpha=0.05):
    """
    Visualize the F-distribution and mark the critical region.

    Parameters:
    - dfn: degrees of freedom for numerator
    - dfd: degrees of freedom for denominator
    - alpha: significance level
    """

    # Define the range for the x-axis
    x = np.linspace(0, 5, 500)
    y = stats.f.pdf(x, dfn, dfd)

    # Critical F-value (right tail)
    f_critical = stats.f.ppf(1 - alpha, dfn, dfd)

    # Plot the F-distribution curve
    plt.figure(figsize=(10, 5))
    plt.plot(x, y, 'b-', label=f'F-distribution\n(df1={dfn}, df2={dfd})')
    plt.fill_between(x, y, 0, where=(x >= f_critical), color='red', alpha=0.3, label=f'Critical Region\nα = {alpha}')
    plt.axvline(f_critical, color='red', linestyle='--', label=f'F-critical = {f_critical:.2f}')

    # Labels and legend
    plt.title("F-Distribution and Critical Region")
    plt.xlabel("F-value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
plot_f_distribution(dfn=5, dfd=20, alpha=0.05)

# %%
#Q.22  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

def one_way_anova_with_boxplot(data, dependent_var, group_var):
    """
    Perform a one-way ANOVA and visualize results with boxplots.

    Parameters:
    - data: pandas DataFrame
    - dependent_var: string, name of dependent variable (numeric)
    - group_var: string, name of group/categorical variable
    """

    # Group data
    groups = [group[dependent_var].values for name, group in data.groupby(group_var)]

    # Perform ANOVA
    f_stat, p_val = stats.f_oneway(*groups)
    print("### One-Way ANOVA Results ###")
    print(f"F-statistic: {f_stat:.4f}")
    print(f"p-value: {p_val:.4f}")

    if p_val < 0.05:
        print("Result: Significant difference between group means (reject H0)")
    else:
        print("Result: No significant difference between group means (fail to reject H0)")

    # Visualization
    print("\n### Boxplot of Groups ###")
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=group_var, y=dependent_var, data=data, palette='Set2')
    plt.title("Group-wise Comparison of Means (Boxplot)")
    plt.grid(True)
    plt.show()
# Generate example data
np.random.seed(1)
df = pd.DataFrame({
    'Score': np.concatenate([
        np.random.normal(loc=70, scale=5, size=30),  # Group A
        np.random.normal(loc=75, scale=5, size=30),  # Group B
        np.random.normal(loc=80, scale=5, size=30)   # Group C
    ]),
    'Group': ['A']*30 + ['B']*30 + ['C']*30
})

# Call the function
one_way_anova_with_boxplot(df, dependent_var='Score', group_var='Group')
# Out:
# ### One-Way ANOVA Results ###
# F-statistic: 43.3528
# p-value: 0.0000
# Result: Significant difference between group means (reject H0)
#
# ### Boxplot of Groups ###
# /tmp/ipython-input-18-83435967.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=group_var, y=dependent_var, data=data, palette='Set2')

# %%
#Q.23 Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means
import numpy as np
import scipy.stats as stats

# Simulate normal data
np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, SD=5, n=30

# Perform one-sample t-test (test if mean != 52)
hypothesized_mean = 52
t_stat, p_value = stats.ttest_1samp(sample, popmean=hypothesized_mean)

print("### One-Sample t-Test ###")
print(f"Sample mean: {np.mean(sample):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Result: Significant difference from hypothesized mean (reject H0)")
else:
    print("Result: No significant difference (fail to reject H0)")
# Out:
# ### One-Sample t-Test ###
# Sample mean: 49.06
# T-statistic: -3.5793
# P-value: 0.0012
# Result: Significant difference from hypothesized mean (reject H0)

# %%
#Q.24.  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results
import numpy as np
from scipy import stats

def chi_square_variance_test(sample, sigma2_0, alpha=0.05, alternative="two-sided"):
    """
    Hypothesis test for the population variance σ² using the χ² distribution.

    H₀ : σ² = sigma2_0
    H₁ : σ² ≠ sigma2_0  (two‑sided, default)
          or  σ² > sigma2_0  (alternative="greater")
          or  σ² < sigma2_0  (alternative="less")

    Parameters
    ----------
    sample : array‑like
        The data (assumed independent and approximately normal).
    sigma2_0 : float
        Variance under H₀.
    alpha : float, default 0.05
        Significance level.
    alternative : {"two-sided", "greater", "less"}

    Returns
    -------
    stat : float
        χ² test statistic.
    p_value : float
        P‑value for the specified alternative.
    ci : tuple(float, float)
        (1 – α) confidence interval for σ².
    """
    sample = np.asarray(sample)
    n        = sample.size
    df       = n - 1
    s2       = np.var(sample, ddof=1)
    stat     = df * s2 / sigma2_0           # χ² statistic

    # p‑value
    if alternative == "two-sided":
        p_value = 2 * min(stats.chi2.cdf(stat, df), 1 - stats.chi2.cdf(stat, df))
    elif alternative == "greater":          # H₁: σ² > σ²₀ (right tail)
        p_value = 1 - stats.chi2.cdf(stat, df)
    else:                                   # H₁: σ² < σ²₀ (left tail)
        p_value = stats.chi2.cdf(stat, df)

    # (1‑α) confidence interval for σ²
    chi2_lower = stats.chi2.ppf(alpha/2,  df)
    chi2_upper = stats.chi2.ppf(1-alpha/2, df)
    ci_lower   = df * s2 / chi2_upper
    ci_upper   = df * s2 / chi2_lower

    return stat, p_value, (ci_lower, ci_upper)
np.random.seed(1)
sample = np.random.normal(loc=0, scale=3, size=20)   # true σ = 3 ⇒ σ² = 9

stat, p, ci = chi_square_variance_test(sample,
                                       sigma2_0=9,
                                       alpha=0.05,
                                       alternative="two-sided")

print(f"Sample size (n):        {len(sample)}")
print(f"Sample variance (s²):   {np.var(sample, ddof=1):.4f}")
print(f"χ² statistic:           {stat:.4f}")
print(f"P‑value:                {p:.4f}")
print(f"95 % CI for σ²:         ({ci[0]:.2f}, {ci[1]:.2f})")
# Out:
# Sample size (n):        20
# Sample variance (s²):   11.4591
# χ² statistic:           24.1914
# P‑value:                0.3778
# 95 % CI for σ²:         (6.63, 24.45)

# %%
#Q.25  Write a Python script to perform a Z-test for comparing proportions between two datasets or groups
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

def z_test_proportions(count1, nobs1, count2, nobs2, alpha=0.05):
    """
    Perform a two-proportion Z-test.

    H₀: p1 = p2 (no difference in proportions)
    H₁: p1 ≠ p2 (two-tailed test by default)

    Parameters:
    - count1, count2: number of successes in group 1 and group 2
    - nobs1, nobs2: total observations in group 1 and group 2
    - alpha: significance level

    Returns:
    - z_stat: Z statistic
    - p_value: corresponding p-value
    - conclusion: result interpretation
    """
    count = np.array([count1, count2])
    nobs  = np.array([nobs1, nobs2])

    z_stat, p_value = proportions_ztest(count, nobs)

    print("### Z-Test for Two Proportions ###")
    print(f"Group 1: {count1}/{nobs1} = {count1/nobs1:.3f}")
    print(f"Group 2: {count2}/{nobs2} = {count2/nobs2:.3f}")
    print(f"Z-statistic: {z_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Conclusion: Significant difference in proportions (reject H₀ at α = {alpha})")
    else:
        print(f"Conclusion: No significant difference in proportions (fail to reject H₀)")
    # Example: Success/failure comparison in two groups
# Group 1: 45 successes out of 100
# Group 2: 30 successes out of 90

z_test_proportions(count1=45, nobs1=100, count2=30, nobs2=90)
# Out:
# ### Z-Test for Two Proportions ###
# Group 1: 45/100 = 0.450
# Group 2: 30/90 = 0.333
# Z-statistic: 1.6427
# P-value: 0.1004
# Conclusion: No significant difference in proportions (fail to reject H₀)

# %%
#Q.26  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def f_test_variance(data1, data2, alpha=0.05):
    """
    Perform an F-test to compare variances of two datasets.

    H₀: σ1² = σ2² (variances are equal)
    H₁: σ1² ≠ σ2² (variances are different)

    Parameters:
    - data1, data2: Arrays or lists of numeric values
    - alpha: Significance level (default = 0.05)

    Returns:
    - Prints F-statistic, p-value, and conclusion
    - Plots F-distribution with critical regions and test statistic
    """

    data1 = np.array(data1)
    data2 = np.array(data2)

    # Sample sizes and variances
    n1, n2 = len(data1), len(data2)
    var1, var2 = np.var(data1, ddof=1), np.var(data2, ddof=1)

    # F-statistic: larger variance / smaller variance (to ensure F ≥ 1)
    if var1 >= var2:
        f_stat = var1 / var2
        dfn, dfd = n1 - 1, n2 - 1
    else:
        f_stat = var2 / var1
        dfn, dfd = n2 - 1, n1 - 1

    # Two-tailed p-value
    p_value = 2 * min(stats.f.cdf(f_stat, dfn, dfd), 1 - stats.f.cdf(f_stat, dfn, dfd))

    # Critical values
    f_crit_low = stats.f.ppf(alpha / 2, dfn, dfd)
    f_crit_high = stats.f.ppf(1 - alpha / 2, dfn, dfd)

    # Print results
    print("### F-Test for Variance Comparison ###")
    print(f"Sample 1 Variance: {var1:.4f}, Sample Size: {n1}")
    print(f"Sample 2 Variance: {var2:.4f}, Sample Size: {n2}")
    print(f"F-statistic: {f_stat:.4f}")
    print(f"P-value: {p_value:.4f}")
    print(f"Critical F range (α={alpha}): < {f_crit_low:.4f} or > {f_crit_high:.4f}")

    if f_stat < f_crit_low or f_stat > f_crit_high:
        print("Conclusion: Variances are significantly different (reject H₀)")
    else:
        print("Conclusion: No significant difference in variances (fail to reject H₀)")

    # Plot F-distribution
    x = np.linspace(0.1, 5, 500)
    y = stats.f.pdf(x, dfn, dfd)

    plt.figure(figsize=(10, 5))
    plt.plot(x, y, 'b-', label='F-distribution')
    plt.axvline(f_stat, color='black', linestyle='--', label=f'F-stat = {f_stat:.2f}')
    plt.fill_between(x, y, 0, where=(x < f_crit_low) | (x > f_crit_high), color='red', alpha=0.3, label='Rejection Region')
    plt.axvline(f_crit_low, color='red', linestyle='--', label=f'Critical Low = {f_crit_low:.2f}')
    plt.axvline(f_crit_high, color='red', linestyle='--', label=f'Critical High = {f_crit_high:.2f}')

    plt.title("F-distribution: Variance Comparison")
    plt.xlabel("F-value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True)
    plt.show()
  # Simulate two samples with different variances
np.random.seed(0)
sample1 = np.random.normal(0, 5, 30)    # variance ≈ 25
sample2 = np.random.normal(0, 3, 30)    # variance ≈ 9

f_test_variance(sample1, sample2)
# Out:
# ### F-Test for Variance Comparison ###
# Sample 1 Variance: 30.2681, Sample Size: 30
# Sample 2 Variance: 7.5225, Sample Size: 30
# F-statistic: 4.0237
# P-value: 0.0003
# Critical F range (α=0.05): < 0.4760 or > 2.1010
# Conclusion: Variances are significantly different (reject H₀)

# %%
#Q.27  Perform a Chi-square test for goodness of fit with simulated data and analyze the results.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def chi_square_goodness_of_fit(observed, expected_probs, alpha=0.05):
    """
    Perform Chi-square goodness-of-fit test.

    H₀: Observed frequencies follow the expected distribution.
    H₁: Observed frequencies do not follow the expected distribution.

    Parameters:
    - observed: list or array of observed counts
    - expected_probs: list of expected probabilities (must sum to 1)
    - alpha: significance level (default = 0.05)
    """

    observed = np.array(observed)
    expected = np.array(expected_probs) * sum(observed)

    # Perform chi-square goodness-of-fit test
    chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

    print("### Chi-Square Goodness-of-Fit Test ###")
    print(f"Observed Counts: {observed}")
    print(f"Expected Counts: {np.round(expected, 2)}")
    print(f"Chi-square Statistic: {chi2_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Conclusion: Significant difference (reject H₀ at α = {alpha})")
    else:
        print(f"Conclusion: No significant difference (fail to reject H₀)")

    # Bar plot
    categories = [f"C{i+1}" for i in range(len(observed))]
    x = np.arange(len(categories))
    width = 0.35

    plt.figure(figsize=(8, 5))
    plt.bar(x - width/2, observed, width, label='Observed', color='skyblue')
    plt.bar(x + width/2, expected, width, label='Expected', color='lightgreen')
    plt.xticks(x, categories)
    plt.title("Observed vs Expected Frequencies")
    plt.ylabel("Count")
    plt.legend()
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.show()
  # Simulate observed counts (e.g., 4 categories)
np.random.seed(0)
observed_counts = np.random.multinomial(n=100, pvals=[0.25, 0.25, 0.25, 0.25])

# Assume equal expected probabilities
expected_probs = [0.25, 0.25, 0.25, 0.25]

# Run test
chi_square_goodness_of_fit(observed_counts, expected_probs)
# Out:
# ### Chi-Square Goodness-of-Fit Test ###
# Observed Counts: [25 27 25 23]
# Expected Counts: [25. 25. 25. 25.]
# Chi-square Statistic: 0.3200
# P-value: 0.9562
# Conclusion: No significant difference (fail to reject H₀)
